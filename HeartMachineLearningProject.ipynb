# %% [markdown]
# <a href="https://colab.research.google.com/github/aysha7711/GraphTheory/blob/main/HeartMachineLearningProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

heart_dataset = pd.read_csv('/content/heart.csv')
heart_dataset.head()
heart_dataset.shape
heart_dataset.describe()
heart_dataset['target'].value_counts()
heart_dataset.groupby("target").mean()
#separating the data and labels
X = heart_dataset.drop(columns='target', axis= 1)
#storing the data into Y
Y= heart_dataset['target']
print(X)
print(Y)
#data standartdization
scaler= StandardScaler()
scaler.fit(X)
#tranpose
standardized_data = scaler.transform(X)
print(standardized_data)
X=standardized_data # data
Y=heart_dataset['target'] #model
print(X) #data in X
print(Y) #labels in Y
#spliting the data into training and testing data
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)
print(X.shape, X_train.shape, X_test.shape)
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  ca  thal
# 0      52    1   0       125   212    0        1      168      0      1.0      2   2     3
# 1      53    1   0       140   203    1        0      155      1      3.1      0   0     3
# 2      70    1   0       145   174    0        1      125      1      2.6      0   0     3
# 3      61    1   0       148   203    0        1      161      0      0.0      2   1     3
# 4      62    0   0       138   294    1        1      106      0      1.9      1   3     2
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...    ...  ..   ...
# 1020   59    1   1       140   221    0        1      164      1      0.0      2   0     2
# 1021   60    1   0       125   258    0        0      141      1      2.8      1   1     3
# 1022   47    1   0       110   275    0        0      118      1      1.0      1   1     2
# ...

# %%
#spliting the data into training and testing data
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (1025, 13) (820, 13) (205, 13)

# %%
#training the model
classifier =svm.SVC(kernel='linear')
#tarining the support vector machine classifier
classifier.fit(X_train, Y_train)
# Out:
# SVC(kernel='linear')

# %%
#model evaluation
#accuracy_score
#accuracy score from the traning data
X_train_prediction = classifier.predict(X_train)
training_data_accuracy=accuracy_score(X_train_prediction, Y_train)
print('accuracy_score of the training data', training_data_accuracy)

# %%
#model evaluation
#accuracy_score
#accuracy score from the test data
X_test_prediction = classifier.predict(X_test)
testing_data_accuracy=accuracy_score(X_test_prediction, Y_test)
print('accuracy_score of the test data', testing_data_accuracy)

# %%
#making the predictive system
input_data=(71,0,0,112,149,0,1,125,0,1.6,1,0,2)

#change the input data to numpy array
input_data_as_numpy_array = np.asarray(input_data)
#reshape the array a swe are predicting for one instance
input_data_reshape=input_data_as_numpy_array.reshape(1, -1)
#standardoze the input data
std_data =scaler.transform(input_data_reshape)
print (std_data)
prediction= classifier.predict(std_data)
print(prediction)
if (prediction[0]==0):
  print ('the person has not heart disease')
else:
  print ('the person has heart disease')
# Out:
# [[ 1.82687503 -1.51170646 -0.91575542 -1.12014597 -1.88103566 -0.41887792
#    0.89125488 -1.04869198 -0.71228712  0.44997602 -0.6241209  -0.73197147
#   -0.52212231]]
# [1]
# the person has heart disease
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
# Out:
# accuracy_score of the test data 0.8195121951219512
